# %%
import os

from IPython.display import Markdown, display
from agent_framework.a2a import A2AAgent
from dotenv import load_dotenv
# Out:
# /Users/sauravprateek/Documents/saurav-codes/neural-nets-codelab/saurav-env/lib/python3.13/site-packages/agent_framework/_skills.py:122: ExperimentalWarning: [SKILLS] SkillResource is experimental and may change or be removed in future versions without notice.
# /Users/sauravprateek/Documents/saurav-codes/neural-nets-codelab/saurav-env/lib/python3.13/site-packages/agent_framework/_harness/_file_access.py:602: ExperimentalWarning: [HARNESS] AgentFileStore is experimental and may change or be removed in future versions without notice.

# %%
host = 'localhost'
port = 9999
base_url = f"http://{host}:{port}"

# %%
# Create A2A agent with direct URL configuration
chat_agent = A2AAgent(
    name="ChatAgent",
    url=base_url,
)

# %%
prompt = "What are some well known AI Engineering design patterns?"
response = await chat_agent.run(prompt)

# %%
display(Markdown(response.text))
# Out:
# AI Engineering design patterns have evolved significantly, especially with the recent explosion of Large Language Models (LLMs). Today, these patterns bridge the gap between experimental data science and robust, production-ready software engineering.
#
# Here are the most well-known AI Engineering design patterns, broken down by **Generative AI (LLMs)**, **Architecture & Serving**, and **MLOps & Deployment**.
#
# ---
#
# ### 1. Generative AI & LLM Patterns
# These patterns deal specifically with how to integrate and orchestrate foundation models.
#
# *   **Retrieval-Augmented Generation (RAG):**
#     *   **What it is:** Instead of relying solely on an LLM’s internal memory, a system first retrieves relevant facts from an external database (usually a vector database) and injects them into the LLM’s prompt.
#     *   **Why use it:** Reduces hallucinations, allows the AI to access private/enterprise data, and prevents the need to constantly retrain models on new information.
# *   **ReAct (Reasoning and Acting) / Agentic Workflow:**
#     *   **What it is:** The AI is given a prompt that forces it to think step-by-step ("Reason") and then use external tools ("Act")—like calculators, APIs, or web scrapers—to gather information before providing a final answer.
#     *   **Why use it:** Enables LLMs to perform complex, multi-step tasks and interact with external software systems.
# *   **Prompt Chaining / Workflow Pipelines:**
#     *   **What it is:** Breaking a complex task into multiple smaller prompts, where the output of one LLM call becomes the input for the next.
#     *   **Why use it:** LLMs perform better on highly specific tasks. Chaining allows for better error handling, visibility, and quality control than one massive prompt.
# *   **Semantic Caching:**
#     *   **What it is:** Storing previous LLM responses. When a new user query comes in, the system checks if it is *semantically similar* (using embeddings) to a cached query. If it is, it returns the cached response instead of calling the LLM.
#     *   **Why use it:** Drastically reduces API costs and latency.
# *   **Query Routing:**
#     *   **What it is:** An initial, lightweight classification model (or small LLM) analyzes the user prompt and routes it to the most appropriate model. (e.g., Simple chat goes to a fast, cheap model; complex coding questions go to a large, expensive model).
#     *   **Why use it:** Optimizes the balance between cost, speed, and accuracy.
#
# ---
#
# ### 2. AI Architecture & Serving Patterns
# These patterns address how AI models are hosted and how they interact with traditional software.
#
# *   **Model-as-a-Service (MaaS) / Synchronous API:**
#     *   **What it is:** The AI model is wrapped in a microservice (e.g., using FastAPI or Flask) and accessed via REST or gRPC.
#     *   **Why use it:** Decouples the model from the application logic, allowing them to scale independently.
# *   **Batch / Offline Inference:**
#     *   **What it is:** The model does not make predictions in real-time. Instead, it runs on a schedule (e.g., nightly), processes millions of records, and writes the predictions to a database for the application to read later.
#     *   **Why use it:** Highly efficient for tasks where real-time answers aren't needed, like generating weekly product recommendations or scoring credit risk.
# *   **Streaming / Event-Driven Inference:**
#     *   **What it is:** The model is subscribed to a message broker (like Apache Kafka). When an event occurs (e.g., a credit card transaction), the model instantly makes a prediction and emits the result.
#     *   **Why use it:** Ideal for fraud detection, real-time dynamic pricing, and IoT sensor analysis.
# *   **The Cascade Pattern:**
#     *   **What it is:** Using multiple models in sequence. A fast, cheap, but less accurate model processes all data first. If it is uncertain, it passes the data to a larger, slower, more accurate model.
#     *   **Why use it:** Saves computing power and speeds up average response times.
#
# ---
#
# ### 3. MLOps & Lifecycle Patterns
# These patterns focus on safely deploying, monitoring, and maintaining AI models in production.
#
# *   **Shadow Deployment (Dark Launching):**
#     *   **What it is:** Deploying a new AI model to production alongside the old one. The new model processes live user traffic, but its predictions are *not* shown to the user; they are only logged.
#     *   **Why use it:** Allows engineers to compare the new model's performance against the old model in the real world with zero risk to the user experience.
# *   **A/B Testing & Canary Releases:**
#     *   **What it is:** Routing a small percentage of user traffic (e.g., 5%) to a new model to ensure it doesn't crash or degrade KPIs before rolling it out to 100%.
#     *   **Why use it:** Minimizes the blast radius if a new AI model performs poorly in production.
# *   **Feature Store Pattern:**
#     *   **What it is:** A centralized repository for managing and serving ML features. It ensures that the exact same data transformations used to *train* the model are used when *serving* the model.
#     *   **Why use it:** Prevents "training-serving skew" (a common bug where data looks different in production than it did in the lab).
# *   **AI Gateway / Guardrails:**
#     *   **What it is:** A proxy layer sitting between the application and the AI model. It intercepts requests and responses to check for toxicity, PII (Personally Identifiable Information), or prompt injection attacks.
#     *   **Why use it:** Essential for AI security, compliance, and maintaining brand safety.
#
# ### Summary Recommendation for AI Engineers
# If you are building modern AI applications today, the most critical combination of patterns to master is **Model-as-a-Service** (for standard ML) and **RAG + Semantic Caching + AI Gateway** (for Generative AI applications).
