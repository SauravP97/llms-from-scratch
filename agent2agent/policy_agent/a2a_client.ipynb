# %%
import os

from IPython.display import Markdown, display
from agent_framework.a2a import A2AAgent
from dotenv import load_dotenv

# %%
host = "localhost"
port = 9999
base_url = f"http://{host}:{port}"

# %%
# Create A2A agent with direct URL configuration
policy_agent = A2AAgent(
    name="PolicyAgent",
    url=base_url,
)

# %%
prompt = "How much would I pay for mental health therapy?"
response = await policy_agent.run(prompt)

# %%
display(Markdown(response.text))
# Out:
# The cost of mental health therapy can vary wildly depending on whether you have insurance, where you live, and the type of therapist you see.
#
# Here is a breakdown of what you can expect to pay (based on U.S. averages), along with ways to make it more affordable.
#
# ### 1. Paying Out-of-Pocket (No Insurance)
# If you are paying cash without any insurance, the average cost typically ranges from **$100 to $200 per session**.
# * In smaller towns or rural areas, it might be closer to **$75–$125**.
# * In major cities (like New York, Los Angeles, or San Francisco), rates frequently run between **$200 and $300+** per session.
#
# ### 2. Paying With Health Insurance
# If you have health insurance that covers mental health (which most ACA-compliant plans do), your costs will be much lower, provided you see an **in-network** therapist.
# * **Copays:** You will usually pay a copay of **$20 to $50 per session**.
# * **Deductibles:** If you have a high-deductible health plan, you may have to pay the full contracted rate (e.g., $100/session) out-of-pocket until you reach your deductible.
# * *Tip:* Always call the number on the back of your insurance card and ask: *"What are my in-network and out-of-network benefits for outpatient mental health visits?"*
#
# ### 3. Factors That Affect the Price
# * **The Therapist's Credentials:**
#   * **Psychiatrists (MD/DO):** The most expensive (can be $200–$500+ for an initial evaluation). They primarily prescribe medication.
#   * **Psychologists (PhD/PsyD):** Usually charge $150–$250+.
#   * **Master’s Level Therapists (LCSW, LMFT, LPC):** The most common for talk therapy. They generally charge $100–$150+.
# * **Online vs. In-Person:** Online therapy platforms (like BetterHelp or Talkspace) operate on subscription models, usually costing **$240 to $400 per month** (which breaks down to about $60–$100 per week).
#
# ### 4. How to Find Affordable Therapy
# If standard rates are out of your budget, you have several options:
#
# * **Sliding Scale Therapists:** Many therapists reserve a few spots for clients who cannot afford their full fee. They will lower the price based on your income (sometimes dropping it to $50–$80 a session). You just have to ask if they offer a "sliding scale."
# * **Open Path Psychotherapy Collective:** This is a non-profit network of mental health professionals dedicated to providing affordable, in-office and online care. If you join (for a one-time lifetime fee of $65), sessions cost between **$40 and $70**.
# * **University Training Clinics:** If you live near a university with a psychology or social work graduate program, they often have clinics where student therapists (supervised by licensed doctors) provide therapy for as little as **$10 to $50 a session**.
# * **Community Mental Health Centers:** State or county-funded clinics offer services based on what you can afford, sometimes offering therapy for free or a very low cost if you have a low income.
# * **Employee Assistance Programs (EAPs):** Check with your HR department at work. Many employers offer an EAP that provides **3 to 8 free therapy sessions** per year.
#
# **Next Step:** A great way to start looking is to go to **PsychologyToday.com**, put in your zip code, and use the filters to select your insurance provider to see who is in your area and what they charge.
